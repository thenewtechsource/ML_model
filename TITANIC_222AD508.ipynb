# %% [markdown]
# <a href="https://colab.research.google.com/github/thenewtechsource/ML_model/blob/main/TITANIC_222AD508.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
df= pd.read_csv("/content/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df= df.dropna()

# %%
df1= df.drop(columns=['Name','Sex','Ticket','Cabin','Embarked'])

# %%
df1.groupby('Survived').mean()
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare
# Survived
# 0          402.983333  1.216667  41.350000  0.366667  0.450000  64.048262
# 1          480.918699  1.178862  32.905854  0.512195  0.487805  85.821107

# %%
df2= df[['Survived','Sex','Age']]
df2
# Out:
#      Survived     Sex   Age
# 1           1  female  38.0
# 3           1  female  35.0
# 6           0    male  54.0
# 10          1  female   4.0
# 11          1  female  58.0
# ..        ...     ...   ...
# 871         1  female  47.0
# 872         0    male  33.0
# 879         1  female  56.0
# 887         1  female  19.0
# 889         1    male  26.0
#
# [183 rows x 3 columns]

# %%
df3= pd.get_dummies(df2,dtype='int')
df3
# Out:
#      Survived   Age  Sex_female  Sex_male
# 1           1  38.0           1         0
# 3           1  35.0           1         0
# 6           0  54.0           0         1
# 10          1   4.0           1         0
# 11          1  58.0           1         0
# ..        ...   ...         ...       ...
# 871         1  47.0           1         0
# 872         0  33.0           0         1
# 879         1  56.0           1         0
# 887         1  19.0           1         0
# 889         1  26.0           0         1
#
# [183 rows x 4 columns]

# %%
from sklearn.tree import DecisionTreeClassifier
X= df3.drop(columns=['Survived'])
Y= df3[['Survived']]

# %%
model= DecisionTreeClassifier()
model.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
ans= model.predict([[38,1,0]])
print(ans)
# Out:
# [1]

# %%
model.score(X,Y)
# Out:
# 0.9180327868852459

# %%
n= int(input('Enter no of people: '))
for i in range(1,n+1):
    age= int(input('Enter age: '))
    sex= input('Enter male or female: ')
    if sex=='male':
        ans= model.predict([[age,0,1]])
        print(ans)
    elif sex=='female':
        ans= model.predict([[age,1,0]])
        print(ans)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-b00299e819df> in <cell line: 2>()
#       1 n= int(input('Enter no of people: '))
#       2 for i in range(1,n+1):
# ----> 3     age= int(input('Enter age: '))
#       4     sex= input('Enter male or female: ')
#       5     if sex=='male':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
from sklearn.linear_model import LogisticRegression
X1= df3.drop(columns=['Survived'])
Y1= df3[['Survived']]

# %%
model1= LogisticRegression()
model1.fit(X1,Y1)
# Out:
# LogisticRegression()

# %%
ans1= model1.predict([[38,1,0]])
print(ans1)
# Out:
# [1]

# %%
model1.score(X1,Y1)
# Out:
# 0.7650273224043715
